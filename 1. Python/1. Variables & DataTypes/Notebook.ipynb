# %% [markdown]
# # Variable Declaration and Types

# %%
x = 10          # int
y = 3.14        # float
name = "Esmail" # string
is_active = True # boolean

# %% [markdown]
# # Type Conversion

# %%
a = 5
b = float(a)   # 5.0
c = str(a)     # "5"

print(a)
print(b)
print(c)
# Out:
# 5
# 5.0
# 5

# %% [markdown]
# # Printing and Checking Types

# %%
print(type(x))
# Out:
# <class 'int'>
